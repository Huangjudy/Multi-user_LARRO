# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#df = pd.read_csv("./Desktop/碩論/數據資料/20220602/Networkusage/Combine_All_0710_1.csv")  # LARR
#df = pd.read_csv("./Desktop/碩論/數據資料/20220602/Networkusage/Combine_All_0710_without_optimization.csv")  # LARR_static
#df = pd.read_csv("./Desktop/碩論/數據資料/20220602/Networkusage/Combine_All_0710_old_streaming.csv") # Traditional
#df = pd.read_csv("C:/Users/IPC_LAB/Desktop/data/1_obj_without_sizeopt.csv")
#df = pd.read_csv("C:/Users/IPC_LAB/Desktop/data/1_obj_with_sizeopt.csv")
#df = pd.read_csv("C:/Users/IPC_LAB/Desktop/data/2obj_combine_without_sizeopt_1.csv")
df = pd.read_csv("C:/Users/IPC_LAB/Desktop/data/no_size_without_combine_2_1.csv")

# %%
df = df[~df['Protocol'].str.contains('STUN')]
df = df[~df['Protocol'].str.contains('TCP')]
df_data = df[~df['Protocol'].str.contains('HTTP')]
df_protocol = df_data.groupby('Protocol').Source.count()
df_protocol.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Protocol'>

# %%
df_ClienttoServer = df_data[df_data['Source'] == '140.115.152.169']
#df_ClienttoServer = df_data[df_data['Source'] == '140.115.197.252']
df_ServertoClient = df_data[df_data['Source'] == '140.115.152.173']
df_ServertoClient
# Out:
#            No.        Time           Source      Destination  Protocol  \
# 0            1    0.000000  140.115.152.173  140.115.152.169       UDP
# 1            2    0.000032  140.115.152.173  140.115.152.169       UDP
# 2            3    0.000045  140.115.152.173  140.115.152.169       UDP
# 3            4    0.000057  140.115.152.173  140.115.152.169       UDP
# 4            5    0.000069  140.115.152.173  140.115.152.169       UDP
# ...        ...         ...              ...              ...       ...
# 136812  198272  245.243221  140.115.152.173  140.115.152.169       UDP
# 136814  198274  245.244147  140.115.152.173  140.115.152.169  DTLSv1.2
# 136815  198277  245.249180  140.115.152.173  140.115.152.169       UDP
# 136816  198278  245.249256  140.115.152.173  140.115.152.169       UDP
# 136817  198279  245.249321  140.115.152.173  140.115.152.169       UDP
#
#         Length                      Info
# 0          112    60573  >  49670 Len=70
# 1          865   60573  >  49670 Len=823
# 2          866   60573  >  49670 Len=824
# 3          866   60573  >  49670 Len=824
# 4          891   60573  >  49670 Len=849
# ...        ...                       ...
# 136812     904   60573  >  49670 Len=862
# 136814      99          Application Data
# 136815     112    60573  >  49670 Len=70
# 136816    1121  60573  >  49670 Len=1079
# 136817    1122  60573  >  49670 Len=1080
#
# [96811 rows x 7 columns]

# %%
#時間界線
lpper = 0
upper = 240

# %%
df_ClienttoServer = df_ClienttoServer[ df_ClienttoServer['Time'].between(lpper,upper)]
df_ClienttoServer
# Out:
#            No.        Time           Source      Destination  Protocol  \
# 7            8    0.001639  140.115.152.169  140.115.152.173  DTLSv1.2
# 8           10    0.005395  140.115.152.169  140.115.152.173  DTLSv1.2
# 10          15    0.012547  140.115.152.169  140.115.152.173  DTLSv1.2
# 13          20    0.018873  140.115.152.169  140.115.152.173  DTLSv1.2
# 17          29    0.025406  140.115.152.169  140.115.152.173  DTLSv1.2
# ...        ...         ...              ...              ...       ...
# 134467  194687  239.965185  140.115.152.169  140.115.152.173  DTLSv1.2
# 134474  194698  239.973864  140.115.152.169  140.115.152.173  DTLSv1.2
# 134479  194707  239.981221  140.115.152.169  140.115.152.173  DTLSv1.2
# 134480  194709  239.988527  140.115.152.169  140.115.152.173  DTLSv1.2
# 134484  194713  239.995714  140.115.152.169  140.115.152.173  DTLSv1.2
#
#         Length              Info
# 7          135  Application Data
# 8          135  Application Data
# 10         135  Application Data
# 13         135  Application Data
# 17         135  Application Data
# ...        ...               ...
# 134467     135  Application Data
# 134474     135  Application Data
# 134479     135  Application Data
# 134480     135  Application Data
# 134484     135  Application Data
#
# [36041 rows x 7 columns]

# %%
df_ServertoClient = df_ServertoClient[ df_ServertoClient['Time'].between(lpper,upper) ]
df_ServertoClient
# Out:
#            No.        Time           Source      Destination Protocol  Length  \
# 0            1    0.000000  140.115.152.173  140.115.152.169      UDP     112
# 1            2    0.000032  140.115.152.173  140.115.152.169      UDP     865
# 2            3    0.000045  140.115.152.173  140.115.152.169      UDP     866
# 3            4    0.000057  140.115.152.173  140.115.152.169      UDP     866
# 4            5    0.000069  140.115.152.173  140.115.152.169      UDP     891
# ...        ...         ...              ...              ...      ...     ...
# 134483  194712  239.989977  140.115.152.173  140.115.152.169      UDP     785
# 134485  194714  239.996237  140.115.152.173  140.115.152.169      UDP    1053
# 134486  194715  239.996293  140.115.152.173  140.115.152.169      UDP    1053
# 134487  194716  239.996322  140.115.152.173  140.115.152.169      UDP    1053
# 134488  194717  239.996335  140.115.152.173  140.115.152.169      UDP    1054
#
#                             Info
# 0         60573  >  49670 Len=70
# 1        60573  >  49670 Len=823
# 2        60573  >  49670 Len=824
# 3        60573  >  49670 Len=824
# 4        60573  >  49670 Len=849
# ...                          ...
# 134483   60573  >  49670 Len=743
# 134485  60573  >  49670 Len=1011
# 134486  60573  >  49670 Len=1011
# 134487  60573  >  49670 Len=1011
# 134488  60573  >  49670 Len=1012
#
# [95285 rows x 7 columns]

# %%
list_ServertoClientnetworkusage = []
list_axisxServertoClient = []
for i in range(lpper,upper):
    df_part = df_ServertoClient[ df_ServertoClient['Time'].between(i,i+1) ]
    totally_byte_per_second = df_part['Length'].sum()  #每秒多少bytes
    totally_bits_per_second = totally_byte_per_second * 8 #每秒多少bits
    Kbits_per_second = totally_bits_per_second / 1024
    list_ServertoClientnetworkusage.append(Kbits_per_second)
    list_axisxServertoClient.append(i)
    print( '使用了 {} Kb' .format(Kbits_per_second))
# Out:
# 使用了 1946.7578125 Kb
# 使用了 1859.515625 Kb
# 使用了 1780.96875 Kb
# 使用了 1293.984375 Kb
# 使用了 1511.421875 Kb
# 使用了 5074.5390625 Kb
# 使用了 7363.75 Kb
# 使用了 4226.125 Kb
# 使用了 1811.953125 Kb
# 使用了 1432.46875 Kb
# 使用了 1793.6875 Kb
# 使用了 1868.546875 Kb
# 使用了 2346.2109375 Kb
# 使用了 2190.90625 Kb
# 使用了 2803.2421875 Kb
# 使用了 2662.4453125 Kb
# 使用了 3119.3828125 Kb
# 使用了 2920.0390625 Kb
# 使用了 3453.203125 Kb
# 使用了 3194.9375 Kb
# 使用了 2801.125 Kb
# 使用了 2114.9921875 Kb
# 使用了 2555.8125 Kb
# 使用了 2392.8671875 Kb
# 使用了 2640.3125 Kb
# 使用了 2343.359375 Kb
# 使用了 2498.78125 Kb
# 使用了 6630.8359375 Kb
# 使用了 5904.859375 Kb
# 使用了 2981.546875 Kb
# 使用了 1126.3984375 Kb
# 使用了 1411.34375 Kb
# 使用了 3568.8046875 Kb
# 使用了 1651.8671875 Kb
# 使用了 1729.3125 Kb
# 使用了 2108.3359375 Kb
# 使用了 1835.859375 Kb
# 使用了 1939.109375 Kb
# 使用了 2156.4140625 Kb
# 使用了 2546.6171875 Kb
# 使用了 2170.8203125 Kb
# 使用了 2231.796875 Kb
# 使用了 2413.1953125 Kb
# 使用了 3825.96875 Kb
# 使用了 2969.015625 Kb
# 使用了 2082.515625 Kb
# 使用了 4696.171875 Kb
# 使用了 2609.8515625 Kb
# 使用了 1510.265625 Kb
# 使用了 1649.1796875 Kb
# 使用了 1763.3203125 Kb
# 使用了 1598.2578125 Kb
# 使用了 2085.515625 Kb
# 使用了 2681.5625 Kb
# 使用了 2877.21875 Kb
# 使用了 2966.3359375 Kb
# 使用了 2810.0703125 Kb
# 使用了 2559.2109375 Kb
# 使用了 2632.0703125 Kb
# 使用了 1916.78125 Kb
# 使用了 2224.296875 Kb
# 使用了 4018.5078125 Kb
# 使用了 3546.7734375 Kb
# 使用了 1619.3125 Kb
# 使用了 2491.421875 Kb
# 使用了 4143.8984375 Kb
# 使用了 4053.875 Kb
# 使用了 1456.578125 Kb
# 使用了 2152.109375 Kb
# 使用了 2078.953125 Kb
# 使用了 2227.5859375 Kb
# 使用了 2680.1015625 Kb
# 使用了 2579.859375 Kb
# 使用了 3184.34375 Kb
# 使用了 4436.421875 Kb
# 使用了 1749.9296875 Kb
# 使用了 1268.8359375 Kb
# 使用了 1307.3671875 Kb
# 使用了 1633.625 Kb
# 使用了 2125.1796875 Kb
# 使用了 1986.0546875 Kb
# 使用了 2085.46875 Kb
# 使用了 2316.96875 Kb
# 使用了 2284.3984375 Kb
# 使用了 2596.9296875 Kb
# 使用了 1912.4453125 Kb
# 使用了 2219.515625 Kb
# 使用了 1975.375 Kb
# 使用了 2796.4921875 Kb
# 使用了 3737.078125 Kb
# 使用了 2611.953125 Kb
# 使用了 2937.21875 Kb
# 使用了 3344.4609375 Kb
# 使用了 3997.8203125 Kb
# 使用了 3591.984375 Kb
# 使用了 2180.890625 Kb
# 使用了 3114.390625 Kb
# 使用了 2400.078125 Kb
# 使用了 2446.3359375 Kb
# 使用了 1983.734375 Kb
# 使用了 3479.9296875 Kb
# 使用了 5601.515625 Kb
# 使用了 3345.25 Kb
# 使用了 2448.3828125 Kb
# 使用了 2528.140625 Kb
# 使用了 2741.625 Kb
# 使用了 4138.7109375 Kb
# 使用了 4603.0078125 Kb
# 使用了 1984.9765625 Kb
# 使用了 1521.59375 Kb
# 使用了 1819.390625 Kb
# 使用了 1839.984375 Kb
# 使用了 2249.078125 Kb
# 使用了 2163.109375 Kb
# 使用了 2662.6171875 Kb
# 使用了 3030.2421875 Kb
# 使用了 4259.59375 Kb
# 使用了 2236.765625 Kb
# 使用了 1596.4375 Kb
# 使用了 2092.8671875 Kb
# 使用了 2526.21875 Kb
# 使用了 4369.125 Kb
# 使用了 4174.8125 Kb
# 使用了 2015.6171875 Kb
# 使用了 1817.28125 Kb
# 使用了 1946.84375 Kb
# 使用了 1235.9921875 Kb
# 使用了 3264.5234375 Kb
# 使用了 2081.1953125 Kb
# 使用了 2812.3828125 Kb
# 使用了 3235.09375 Kb
# 使用了 2173.1015625 Kb
# 使用了 1783.71875 Kb
# 使用了 2007.578125 Kb
# 使用了 2247.796875 Kb
# 使用了 2624.8671875 Kb
# 使用了 1579.65625 Kb
# 使用了 2752.75 Kb
# 使用了 7966.1796875 Kb
# 使用了 4664.1640625 Kb
# 使用了 807.328125 Kb
# 使用了 1794.296875 Kb
# 使用了 1493.7578125 Kb
# 使用了 1669.953125 Kb
# 使用了 1756.234375 Kb
# 使用了 1863.7265625 Kb
# 使用了 2132.7734375 Kb
# 使用了 2316.03125 Kb
# 使用了 2678.59375 Kb
# 使用了 2731.40625 Kb
# 使用了 3813.5625 Kb
# 使用了 1239.0859375 Kb
# 使用了 2057.8046875 Kb
# 使用了 2876.8359375 Kb
# 使用了 3770.328125 Kb
# 使用了 1898.8203125 Kb
# 使用了 2240.1484375 Kb
# 使用了 4308.296875 Kb
# 使用了 6058.3046875 Kb
# 使用了 3111.9296875 Kb
# 使用了 1273.234375 Kb
# 使用了 1575.53125 Kb
# 使用了 1311.4765625 Kb
# 使用了 1151.7109375 Kb
# 使用了 3602.3984375 Kb
# 使用了 2375.125 Kb
# 使用了 2570.65625 Kb
# 使用了 2561.3671875 Kb
# 使用了 2615.2109375 Kb
# 使用了 3720.5 Kb
# 使用了 2080.4453125 Kb
# 使用了 1622.1328125 Kb
# 使用了 3599.09375 Kb
# 使用了 4459.3359375 Kb
# 使用了 2820.03125 Kb
# 使用了 2306.625 Kb
# 使用了 4665.0546875 Kb
# 使用了 2513.6484375 Kb
# 使用了 2480.390625 Kb
# 使用了 2189.765625 Kb
# 使用了 2437.1875 Kb
# 使用了 2476.84375 Kb
# 使用了 1806.796875 Kb
# 使用了 2964.8984375 Kb
# 使用了 3923.203125 Kb
# 使用了 4345.53125 Kb
# 使用了 1461.6484375 Kb
# 使用了 1104.5546875 Kb
# 使用了 3070.2265625 Kb
# 使用了 2846.125 Kb
# 使用了 1260.6328125 Kb
# 使用了 1398.4140625 Kb
# 使用了 1519.9765625 Kb
# 使用了 1800.546875 Kb
# 使用了 1851.53125 Kb
# 使用了 1067.6640625 Kb
# 使用了 1363.1640625 Kb
# 使用了 2502.5234375 Kb
# 使用了 3021.2265625 Kb
# 使用了 3025.6875 Kb
# 使用了 3069.4375 Kb
# 使用了 1768.0 Kb
# 使用了 1621.390625 Kb
# 使用了 2350.34375 Kb
# 使用了 5257.453125 Kb
# 使用了 4370.5390625 Kb
# 使用了 1488.3671875 Kb
# 使用了 2270.1953125 Kb
# 使用了 1831.03125 Kb
# 使用了 1997.71875 Kb
# 使用了 1407.3671875 Kb
# 使用了 1571.5234375 Kb
# 使用了 4920.578125 Kb
# 使用了 3279.09375 Kb
# 使用了 1116.1875 Kb
# 使用了 1330.15625 Kb
# 使用了 1451.1015625 Kb
# 使用了 1373.90625 Kb
# 使用了 1584.2890625 Kb
# 使用了 1008.890625 Kb
# 使用了 1549.75 Kb
# 使用了 4374.796875 Kb
# 使用了 1655.71875 Kb
# 使用了 1316.1484375 Kb
# 使用了 2501.546875 Kb
# 使用了 1442.375 Kb
# 使用了 1949.6328125 Kb
# 使用了 2126.078125 Kb
# 使用了 2132.8984375 Kb
# 使用了 2293.6640625 Kb
# 使用了 2615.6015625 Kb
# 使用了 3995.4453125 Kb
# 使用了 2472.3828125 Kb
# 使用了 2231.1796875 Kb
# 使用了 1606.578125 Kb
# 使用了 2257.84375 Kb
# 使用了 2624.125 Kb
# 使用了 3129.203125 Kb
# 使用了 3485.921875 Kb
# 使用了 2536.7890625 Kb

# %%
list_ClienttoServernetworkusage = []
list_axisxClienttoServer = []
for i in range(lpper,upper):
    df_part = df_ClienttoServer[ df_ClienttoServer['Time'].between(i,i+1) ]
    totally_byte_per_second = df_part['Length'].sum()  #每秒多少bytes
    totally_bits_per_second = totally_byte_per_second * 8 #每秒多少bits
    Kbits_per_second = totally_bits_per_second / 1024
    list_ClienttoServernetworkusage.append(Kbits_per_second)
    list_axisxClienttoServer.append(i)
    print( '使用了 {} Kb' .format(Kbits_per_second))
# Out:
# 使用了 164.65625 Kb
# 使用了 161.5390625 Kb
# 使用了 161.109375 Kb
# 使用了 159.984375 Kb
# 使用了 158.8828125 Kb
# 使用了 166.0078125 Kb
# 使用了 198.859375 Kb
# 使用了 187.8046875 Kb
# 使用了 168.6171875 Kb
# 使用了 159.5859375 Kb
# 使用了 161.25 Kb
# 使用了 153.484375 Kb
# 使用了 156.859375 Kb
# 使用了 158.9140625 Kb
# 使用了 164.0 Kb
# 使用了 154.8125 Kb
# 使用了 157.390625 Kb
# 使用了 154.046875 Kb
# 使用了 165.703125 Kb
# 使用了 165.8515625 Kb
# 使用了 155.3671875 Kb
# 使用了 166.828125 Kb
# 使用了 158.078125 Kb
# 使用了 158.7265625 Kb
# 使用了 158.5390625 Kb
# 使用了 158.703125 Kb
# 使用了 157.078125 Kb
# 使用了 172.0859375 Kb
# 使用了 187.484375 Kb
# 使用了 167.109375 Kb
# 使用了 161.625 Kb
# 使用了 155.640625 Kb
# 使用了 164.40625 Kb
# 使用了 160.515625 Kb
# 使用了 159.0078125 Kb
# 使用了 157.7890625 Kb
# 使用了 153.46875 Kb
# 使用了 154.25 Kb
# 使用了 160.0 Kb
# 使用了 164.234375 Kb
# 使用了 159.0703125 Kb
# 使用了 163.8671875 Kb
# 使用了 152.5703125 Kb
# 使用了 168.1953125 Kb
# 使用了 161.7265625 Kb
# 使用了 155.0234375 Kb
# 使用了 163.96875 Kb
# 使用了 164.96875 Kb
# 使用了 158.03125 Kb
# 使用了 156.1796875 Kb
# 使用了 155.8828125 Kb
# 使用了 159.0 Kb
# 使用了 155.3359375 Kb
# 使用了 156.28125 Kb
# 使用了 162.234375 Kb
# 使用了 158.015625 Kb
# 使用了 162.1328125 Kb
# 使用了 158.2734375 Kb
# 使用了 156.71875 Kb
# 使用了 155.4453125 Kb
# 使用了 160.5078125 Kb
# 使用了 167.2421875 Kb
# 使用了 165.2421875 Kb
# 使用了 158.4453125 Kb
# 使用了 153.21875 Kb
# 使用了 171.84375 Kb
# 使用了 168.1015625 Kb
# 使用了 155.4921875 Kb
# 使用了 152.421875 Kb
# 使用了 151.53125 Kb
# 使用了 155.6640625 Kb
# 使用了 157.328125 Kb
# 使用了 156.0625 Kb
# 使用了 157.4375 Kb
# 使用了 172.3828125 Kb
# 使用了 155.21875 Kb
# 使用了 149.5859375 Kb
# 使用了 151.34375 Kb
# 使用了 152.2578125 Kb
# 使用了 155.7578125 Kb
# 使用了 153.859375 Kb
# 使用了 152.171875 Kb
# 使用了 153.4140625 Kb
# 使用了 150.6015625 Kb
# 使用了 153.0546875 Kb
# 使用了 154.4453125 Kb
# 使用了 154.734375 Kb
# 使用了 152.4453125 Kb
# 使用了 153.2734375 Kb
# 使用了 159.890625 Kb
# 使用了 154.4140625 Kb
# 使用了 152.859375 Kb
# 使用了 156.8671875 Kb
# 使用了 164.34375 Kb
# 使用了 161.6328125 Kb
# 使用了 152.9296875 Kb
# 使用了 164.1796875 Kb
# 使用了 149.71875 Kb
# 使用了 154.4765625 Kb
# 使用了 154.2265625 Kb
# 使用了 158.875 Kb
# 使用了 174.90625 Kb
# 使用了 163.3828125 Kb
# 使用了 155.59375 Kb
# 使用了 159.2578125 Kb
# 使用了 152.765625 Kb
# 使用了 164.109375 Kb
# 使用了 171.2265625 Kb
# 使用了 155.921875 Kb
# 使用了 153.3828125 Kb
# 使用了 155.1484375 Kb
# 使用了 153.25 Kb
# 使用了 155.84375 Kb
# 使用了 156.53125 Kb
# 使用了 153.71875 Kb
# 使用了 156.546875 Kb
# 使用了 168.109375 Kb
# 使用了 153.75 Kb
# 使用了 151.703125 Kb
# 使用了 154.40625 Kb
# 使用了 153.0234375 Kb
# 使用了 163.953125 Kb
# 使用了 169.9375 Kb
# 使用了 151.4765625 Kb
# 使用了 154.84375 Kb
# 使用了 150.28125 Kb
# 使用了 151.9765625 Kb
# 使用了 155.4375 Kb
# 使用了 148.046875 Kb
# 使用了 150.6484375 Kb
# 使用了 156.21875 Kb
# 使用了 151.21875 Kb
# 使用了 149.390625 Kb
# 使用了 148.5078125 Kb
# 使用了 150.9453125 Kb
# 使用了 146.546875 Kb
# 使用了 147.640625 Kb
# 使用了 152.625 Kb
# 使用了 176.1953125 Kb
# 使用了 193.40625 Kb
# 使用了 163.8203125 Kb
# 使用了 157.90625 Kb
# 使用了 150.546875 Kb
# 使用了 147.0234375 Kb
# 使用了 148.5390625 Kb
# 使用了 151.8359375 Kb
# 使用了 148.421875 Kb
# 使用了 148.3046875 Kb
# 使用了 153.0 Kb
# 使用了 155.0078125 Kb
# 使用了 159.7265625 Kb
# 使用了 148.515625 Kb
# 使用了 149.390625 Kb
# 使用了 151.21875 Kb
# 使用了 163.875 Kb
# 使用了 150.8828125 Kb
# 使用了 150.6171875 Kb
# 使用了 156.828125 Kb
# 使用了 186.7421875 Kb
# 使用了 167.9921875 Kb
# 使用了 149.7734375 Kb
# 使用了 148.7890625 Kb
# 使用了 148.6640625 Kb
# 使用了 151.9296875 Kb
# 使用了 152.75 Kb
# 使用了 154.515625 Kb
# 使用了 149.0703125 Kb
# 使用了 148.75 Kb
# 使用了 153.609375 Kb
# 使用了 156.359375 Kb
# 使用了 152.34375 Kb
# 使用了 149.9375 Kb
# 使用了 151.9609375 Kb
# 使用了 163.890625 Kb
# 使用了 156.671875 Kb
# 使用了 151.8828125 Kb
# 使用了 160.9140625 Kb
# 使用了 150.453125 Kb
# 使用了 152.0703125 Kb
# 使用了 150.140625 Kb
# 使用了 156.8203125 Kb
# 使用了 150.9609375 Kb
# 使用了 150.6953125 Kb
# 使用了 153.6484375 Kb
# 使用了 160.078125 Kb
# 使用了 171.0859375 Kb
# 使用了 151.9296875 Kb
# 使用了 145.9375 Kb
# 使用了 154.3671875 Kb
# 使用了 151.8828125 Kb
# 使用了 143.7734375 Kb
# 使用了 142.546875 Kb
# 使用了 143.453125 Kb
# 使用了 145.9296875 Kb
# 使用了 145.6953125 Kb
# 使用了 144.3359375 Kb
# 使用了 144.4140625 Kb
# 使用了 143.921875 Kb
# 使用了 149.390625 Kb
# 使用了 151.828125 Kb
# 使用了 150.8515625 Kb
# 使用了 144.5703125 Kb
# 使用了 148.984375 Kb
# 使用了 145.8671875 Kb
# 使用了 161.6640625 Kb
# 使用了 164.53125 Kb
# 使用了 147.3671875 Kb
# 使用了 134.140625 Kb
# 使用了 90.7734375 Kb
# 使用了 113.2890625 Kb
# 使用了 137.6875 Kb
# 使用了 138.609375 Kb
# 使用了 156.5859375 Kb
# 使用了 157.171875 Kb
# 使用了 150.7734375 Kb
# 使用了 147.2421875 Kb
# 使用了 142.609375 Kb
# 使用了 144.5703125 Kb
# 使用了 145.28125 Kb
# 使用了 147.0234375 Kb
# 使用了 143.390625 Kb
# 使用了 161.140625 Kb
# 使用了 145.234375 Kb
# 使用了 145.34375 Kb
# 使用了 149.34375 Kb
# 使用了 143.078125 Kb
# 使用了 146.90625 Kb
# 使用了 143.203125 Kb
# 使用了 145.8046875 Kb
# 使用了 145.625 Kb
# 使用了 146.984375 Kb
# 使用了 161.0859375 Kb
# 使用了 146.140625 Kb
# 使用了 151.4765625 Kb
# 使用了 141.390625 Kb
# 使用了 145.53125 Kb
# 使用了 134.75 Kb
# 使用了 126.7578125 Kb
# 使用了 145.21875 Kb
# 使用了 143.3125 Kb

# %%
fig = plt.figure()
#list_ServertoClientnetworkusage[8:15] = list_ServertoClientnetworkusage[0:7]
plt.plot(list_axisxClienttoServer, list_ClienttoServernetworkusage, 'r')
plt.plot(list_axisxServertoClient, list_ServertoClientnetworkusage, 'g')
plt.legend(('Client to Server', 'Server to Client'), loc='best') # 畫圖例及決定位置
plt.title('Multiplane Streaming')
plt.xlabel('Sample number (sec)')
plt.ylabel('NetworkUsage (Kb)')
plt.show()

# %%
mean_Client_to_Server = sum(list_ClienttoServernetworkusage) / len(list_axisxClienttoServer)
mean_Server_to_Client = sum(list_ServertoClientnetworkusage) / len(list_axisxServertoClient)
print('平均每秒串流至Client的影像資料為 {} Kb'.format(mean_Server_to_Client))
print('平均每秒傳輸至Server的控制資料為 {} Kb'.format(mean_Client_to_Server))
# Out:
# 平均每秒串流至Client的影像資料為 2564.537662760417 Kb
# 平均每秒傳輸至Server的控制資料為 155.01363932291667 Kb

# %%
list_ServertoClientnetworkusagecut = list_ServertoClientnetworkusage[0:30]
print(list_ServertoClientnetworkusagecut)
mean_Server_to_Client_cut = sum(list_ServertoClientnetworkusagecut) / len(list_ServertoClientnetworkusagecut)
print('平均每秒串流至Client的影像資料為 {} Kb (無傳輸任何物件)'.format(mean_Server_to_Client_cut))
# Out:
# [1946.7578125, 1859.515625, 1780.96875, 1293.984375, 1511.421875, 5074.5390625, 7363.75, 4226.125, 1811.953125, 1432.46875, 1793.6875, 1868.546875, 2346.2109375, 2190.90625, 2803.2421875, 2662.4453125, 3119.3828125, 2920.0390625, 3453.203125, 3194.9375, 2801.125, 2114.9921875, 2555.8125, 2392.8671875, 2640.3125, 2343.359375, 2498.78125, 6630.8359375, 5904.859375, 2981.546875]
# 平均每秒串流至Client的影像資料為 2917.2859375 Kb (無傳輸任何物件)

# %%
list_no_size_with_combine = list_ServertoClientnetworkusage

# %%
list_no_size_with_combine
# Out:
# [1263.2578125,
#  1151.203125,
#  1063.5390625,
#  1044.484375,
#  809.765625,
#  1739.5859375,
#  2112.046875,
#  1766.0625,
#  2460.2578125,
#  2792.0625,
#  2835.078125,
#  4041.6015625,
#  3657.328125,
#  2863.6640625,
#  2797.6484375,
#  3339.328125,
#  2514.9296875,
#  1960.4921875,
#  2074.6328125,
#  5045.0546875,
#  4602.921875,
#  1936.6875,
#  1164.15625,
#  1473.140625,
#  1439.9140625,
#  1585.34375,
#  1471.6171875,
#  1665.6796875,
#  1632.4375,
#  1755.5625,
#  2028.7109375,
#  1722.71875,
#  1612.046875,
#  1445.25,
#  1807.03125,
#  1681.3671875,
#  1767.359375,
#  2457.015625,
#  3346.7734375,
#  2348.8046875,
#  1221.1015625,
#  3025.3125,
#  3118.5859375,
#  3424.8046875,
#  2820.796875,
#  2882.859375,
#  3346.5234375,
#  4784.046875,
#  2948.4140625,
#  3262.921875,
#  2907.71875,
#  4343.78125,
#  1728.046875,
#  1525.515625,
#  1635.34375,
#  1313.4140625,
#  1756.03125,
#  2123.3515625,
#  2483.0859375,
#  2157.515625,
#  1580.015625,
#  1809.5390625,
#  2709.34375,
#  2422.390625,
#  1055.8984375,
#  1810.1953125,
#  3965.828125,
#  3175.3203125,
#  4451.4296875,
#  2656.28125,
#  2409.4609375,
#  2131.2109375,
#  1816.515625,
#  2605.078125,
#  2912.078125,
#  2571.0234375,
#  2634.71875,
#  2881.0234375,
#  2336.6875,
#  2247.203125,
#  2713.890625,
#  3875.6640625,
#  2418.1328125,
#  1987.4140625,
#  2020.5703125,
#  2026.96875,
#  2092.546875,
#  2603.3515625,
#  2115.671875,
#  2583.359375,
#  2437.109375,
#  2967.5390625,
#  2691.5,
#  3092.265625,
#  2615.1484375,
#  1856.890625,
#  1710.5234375,
#  3557.9453125,
#  4834.5859375,
#  2691.8125,
#  1908.6796875,
#  1615.2421875,
#  2041.96875,
#  1581.7734375,
#  2812.0859375,
#  3732.5546875,
#  2478.75,
#  2082.4296875,
#  2490.0546875,
#  2165.921875,
#  2351.171875,
#  2745.0703125,
#  3261.0703125,
#  2860.6796875,
#  2578.1328125,
#  3005.9140625,
#  3257.546875,
#  2166.375,
#  1141.3203125,
#  2536.46875,
#  5513.4609375,
#  3766.6640625,
#  2399.9921875,
#  1192.4609375,
#  971.046875,
#  1999.8203125,
#  1716.71875,
#  1503.2265625,
#  1550.9296875,
#  1413.78125,
#  1495.265625,
#  2127.859375,
#  3002.734375,
#  2185.0078125,
#  1655.0703125,
#  1616.34375,
#  1683.828125,
#  1590.484375,
#  1718.9609375,
#  1455.234375,
#  1661.359375,
#  1770.125,
#  1767.7109375,
#  2154.265625,
#  2619.078125,
#  1636.921875,
#  2122.1171875,
#  2065.125,
#  1855.3515625,
#  1892.9765625,
#  1720.2890625,
#  2065.0,
#  2604.609375,
#  3550.4140625,
#  3233.6875,
#  1576.109375,
#  2714.265625,
#  5976.65625,
#  4522.2265625,
#  1710.8828125,
#  1740.46875,
#  1086.6171875,
#  1740.1875,
#  2675.1875,
#  1844.203125,
#  1883.8203125,
#  2111.390625,
#  2140.375,
#  1868.6015625,
#  2180.203125,
#  1971.4765625,
#  1367.9609375,
#  1993.46875,
#  2037.3515625,
#  1818.03125,
#  2426.2890625,
#  3160.953125,
#  2487.4609375,
#  2599.1875,
#  2045.15625,
#  1723.609375,
#  4084.3828125,
#  6800.046875,
#  4801.046875,
#  2754.4140625,
#  1872.078125,
#  1097.3359375,
#  957.7890625,
#  2767.6328125,
#  3014.7265625,
#  1854.6015625,
#  1577.0390625,
#  1989.875,
#  2158.4375,
#  1762.6484375,
#  2184.8671875,
#  2253.3671875,
#  2801.375,
#  2776.1875,
#  2966.46875,
#  4300.6015625,
#  4460.515625,
#  2301.2421875,
#  892.796875,
#  2230.875,
#  2005.9765625,
#  1996.2734375,
#  2100.359375,
#  3119.84375,
#  2683.828125,
#  2275.3515625,
#  1789.734375,
#  1754.8515625,
#  1613.0703125,
#  1790.03125,
#  2016.640625,
#  2171.5390625,
#  2540.6484375,
#  2820.8359375,
#  3665.734375,
#  3991.359375,
#  1791.9453125,
#  1772.75,
#  3354.3203125,
#  3261.234375,
#  2252.5859375,
#  2504.359375,
#  3395.0703125,
#  1980.2421875,
#  1659.3046875,
#  1376.9375,
#  1386.8515625,
#  2471.5,
#  1987.8515625,
#  2218.671875,
#  2584.1484375,
#  2007.9375,
#  2809.578125,
#  3943.765625,
#  4648.6015625]

# %%
list_no_size_without_combine = list_ServertoClientnetworkusage

# %%
list_no_size_without_combine
# Out:
# [1946.7578125,
#  1859.515625,
#  1780.96875,
#  1293.984375,
#  1511.421875,
#  5074.5390625,
#  7363.75,
#  4226.125,
#  1811.953125,
#  1432.46875,
#  1793.6875,
#  1868.546875,
#  2346.2109375,
#  2190.90625,
#  2803.2421875,
#  2662.4453125,
#  3119.3828125,
#  2920.0390625,
#  3453.203125,
#  3194.9375,
#  2801.125,
#  2114.9921875,
#  2555.8125,
#  2392.8671875,
#  2640.3125,
#  2343.359375,
#  2498.78125,
#  6630.8359375,
#  5904.859375,
#  2981.546875,
#  1126.3984375,
#  1411.34375,
#  3568.8046875,
#  1651.8671875,
#  1729.3125,
#  2108.3359375,
#  1835.859375,
#  1939.109375,
#  2156.4140625,
#  2546.6171875,
#  2170.8203125,
#  2231.796875,
#  2413.1953125,
#  3825.96875,
#  2969.015625,
#  2082.515625,
#  4696.171875,
#  2609.8515625,
#  1510.265625,
#  1649.1796875,
#  1763.3203125,
#  1598.2578125,
#  2085.515625,
#  2681.5625,
#  2877.21875,
#  2966.3359375,
#  2810.0703125,
#  2559.2109375,
#  2632.0703125,
#  1916.78125,
#  2224.296875,
#  4018.5078125,
#  3546.7734375,
#  1619.3125,
#  2491.421875,
#  4143.8984375,
#  4053.875,
#  1456.578125,
#  2152.109375,
#  2078.953125,
#  2227.5859375,
#  2680.1015625,
#  2579.859375,
#  3184.34375,
#  4436.421875,
#  1749.9296875,
#  1268.8359375,
#  1307.3671875,
#  1633.625,
#  2125.1796875,
#  1986.0546875,
#  2085.46875,
#  2316.96875,
#  2284.3984375,
#  2596.9296875,
#  1912.4453125,
#  2219.515625,
#  1975.375,
#  2796.4921875,
#  3737.078125,
#  2611.953125,
#  2937.21875,
#  3344.4609375,
#  3997.8203125,
#  3591.984375,
#  2180.890625,
#  3114.390625,
#  2400.078125,
#  2446.3359375,
#  1983.734375,
#  3479.9296875,
#  5601.515625,
#  3345.25,
#  2448.3828125,
#  2528.140625,
#  2741.625,
#  4138.7109375,
#  4603.0078125,
#  1984.9765625,
#  1521.59375,
#  1819.390625,
#  1839.984375,
#  2249.078125,
#  2163.109375,
#  2662.6171875,
#  3030.2421875,
#  4259.59375,
#  2236.765625,
#  1596.4375,
#  2092.8671875,
#  2526.21875,
#  4369.125,
#  4174.8125,
#  2015.6171875,
#  1817.28125,
#  1946.84375,
#  1235.9921875,
#  3264.5234375,
#  2081.1953125,
#  2812.3828125,
#  3235.09375,
#  2173.1015625,
#  1783.71875,
#  2007.578125,
#  2247.796875,
#  2624.8671875,
#  1579.65625,
#  2752.75,
#  7966.1796875,
#  4664.1640625,
#  807.328125,
#  1794.296875,
#  1493.7578125,
#  1669.953125,
#  1756.234375,
#  1863.7265625,
#  2132.7734375,
#  2316.03125,
#  2678.59375,
#  2731.40625,
#  3813.5625,
#  1239.0859375,
#  2057.8046875,
#  2876.8359375,
#  3770.328125,
#  1898.8203125,
#  2240.1484375,
#  4308.296875,
#  6058.3046875,
#  3111.9296875,
#  1273.234375,
#  1575.53125,
#  1311.4765625,
#  1151.7109375,
#  3602.3984375,
#  2375.125,
#  2570.65625,
#  2561.3671875,
#  2615.2109375,
#  3720.5,
#  2080.4453125,
#  1622.1328125,
#  3599.09375,
#  4459.3359375,
#  2820.03125,
#  2306.625,
#  4665.0546875,
#  2513.6484375,
#  2480.390625,
#  2189.765625,
#  2437.1875,
#  2476.84375,
#  1806.796875,
#  2964.8984375,
#  3923.203125,
#  4345.53125,
#  1461.6484375,
#  1104.5546875,
#  3070.2265625,
#  2846.125,
#  1260.6328125,
#  1398.4140625,
#  1519.9765625,
#  1800.546875,
#  1851.53125,
#  1067.6640625,
#  1363.1640625,
#  2502.5234375,
#  3021.2265625,
#  3025.6875,
#  3069.4375,
#  1768.0,
#  1621.390625,
#  2350.34375,
#  5257.453125,
#  4370.5390625,
#  1488.3671875,
#  2270.1953125,
#  1831.03125,
#  1997.71875,
#  1407.3671875,
#  1571.5234375,
#  4920.578125,
#  3279.09375,
#  1116.1875,
#  1330.15625,
#  1451.1015625,
#  1373.90625,
#  1584.2890625,
#  1008.890625,
#  1549.75,
#  4374.796875,
#  1655.71875,
#  1316.1484375,
#  2501.546875,
#  1442.375,
#  1949.6328125,
#  2126.078125,
#  2132.8984375,
#  2293.6640625,
#  2615.6015625,
#  3995.4453125,
#  2472.3828125,
#  2231.1796875,
#  1606.578125,
#  2257.84375,
#  2624.125,
#  3129.203125,
#  3485.921875,
#  2536.7890625]

# %%
list_size_with_combine = list_ServertoClientnetworkusage

# %%
list_size_with_combine
# Out:
# [161.515625,
#  163.171875,
#  161.7265625,
#  162.9921875,
#  161.3046875,
#  301.4609375,
#  392.1640625,
#  358.5625,
#  312.2890625,
#  376.484375,
#  379.4296875,
#  401.8125,
#  458.3515625,
#  363.78125,
#  336.1328125,
#  379.7890625,
#  412.34375,
#  324.1328125,
#  341.125,
#  375.4296875,
#  391.5234375,
#  441.6015625,
#  455.8671875,
#  370.515625,
#  369.46875,
#  407.8671875,
#  354.2109375,
#  306.1328125,
#  367.9921875,
#  396.9140625,
#  391.3671875,
#  473.1484375,
#  358.5546875,
#  362.5625,
#  378.0625,
#  419.03125,
#  330.640625,
#  346.0703125,
#  416.5,
#  383.6015625,
#  443.6015625,
#  435.3828125,
#  368.9609375,
#  384.7109375,
#  398.421875,
#  344.765625,
#  303.7109375,
#  388.734375,
#  370.1015625,
#  383.5546875,
#  460.3984375,
#  323.4921875,
#  323.1171875,
#  323.59375,
#  350.6171875,
#  277.8125,
#  308.6796875,
#  328.890625,
#  329.3046875,
#  429.90625,
#  380.7109375,
#  322.1328125,
#  334.7421875,
#  356.4609375,
#  297.640625,
#  282.53125,
#  343.3125,
#  349.375,
#  376.3984375,
#  415.8203125,
#  298.0703125,
#  321.6875,
#  335.4609375,
#  342.8203125,
#  275.6484375,
#  309.125,
#  354.15625,
#  325.46875,
#  424.3984375,
#  360.96875,
#  309.4921875,
#  331.5703125,
#  352.4609375,
#  285.0546875,
#  277.734375,
#  339.5390625,
#  354.2109375,
#  376.5078125,
#  444.3203125,
#  305.015625,
#  308.9296875,
#  335.7734375,
#  332.6875,
#  286.65625,
#  309.671875,
#  348.7734375,
#  343.1484375,
#  437.0234375,
#  350.40625,
#  316.21875,
#  329.7578125,
#  358.5,
#  298.7109375,
#  268.7109375,
#  335.0078125,
#  335.0859375,
#  371.3359375,
#  397.0546875,
#  306.9453125,
#  318.1796875,
#  339.75,
#  340.6796875,
#  278.609375,
#  309.3046875,
#  346.1796875,
#  337.6328125,
#  417.640625,
#  346.8046875,
#  312.0546875,
#  335.1953125,
#  366.921875,
#  285.640625,
#  273.90625,
#  354.3046875,
#  341.84375,
#  379.59375,
#  430.828125,
#  302.390625,
#  311.0078125,
#  337.421875,
#  334.4140625,
#  280.6875,
#  328.2734375,
#  348.46875,
#  319.8515625,
#  450.3515625,
#  340.296875,
#  310.5234375,
#  358.9765625,
#  360.3984375,
#  276.9296875,
#  284.25,
#  321.515625,
#  340.09375,
#  410.734375,
#  398.3359375,
#  314.59375,
#  321.015625,
#  347.7890625,
#  313.25,
#  269.3671875,
#  322.578125,
#  349.1953125,
#  349.2734375,
#  419.984375,
#  319.96875,
#  307.265625,
#  330.9609375,
#  364.3671875,
#  279.78125,
#  275.2890625,
#  350.46875,
#  341.25,
#  411.375,
#  405.765625,
#  317.9921875,
#  323.2109375,
#  341.1875,
#  321.078125,
#  275.3671875,
#  349.90625,
#  353.4609375,
#  330.96875,
#  429.421875,
#  317.7265625,
#  307.4296875,
#  338.078125,
#  362.875,
#  270.421875,
#  292.859375,
#  350.671875,
#  321.0390625,
#  419.03125,
#  387.9375,
#  308.984375,
#  322.6875,
#  351.8046875,
#  302.984375,
#  273.25,
#  338.40625,
#  330.7421875,
#  371.9140625,
#  430.5625,
#  296.7890625,
#  311.984375,
#  340.3515625,
#  352.6796875,
#  275.703125,
#  302.8125,
#  337.0234375,
#  338.140625,
#  422.6171875,
#  362.53125,
#  314.1484375,
#  322.1640625,
#  359.2734375,
#  305.65625,
#  269.640625,
#  338.4375,
#  354.5,
#  350.515625,
#  430.3515625,
#  303.234375,
#  322.078125,
#  329.859375,
#  351.15625,
#  271.03125,
#  297.984375,
#  349.203125,
#  326.140625,
#  408.828125,
#  366.1171875,
#  304.8984375,
#  325.0078125,
#  354.890625,
#  304.171875,
#  254.4296875,
#  325.890625,
#  355.65625,
#  395.9140625,
#  396.59375,
#  276.265625,
#  301.9765625,
#  327.125,
#  340.1875,
#  269.2734375,
#  302.90625,
#  344.125,
#  316.6796875,
#  414.7421875]

# %%
list_size_without_combine = list_ServertoClientnetworkusage

# %%
list_size_without_combine
# Out:
# [187.203125,
#  185.1484375,
#  185.1953125,
#  180.875,
#  186.3125,
#  314.375,
#  608.3359375,
#  625.234375,
#  619.7421875,
#  788.65625,
#  543.1953125,
#  544.34375,
#  626.421875,
#  634.84375,
#  440.7734375,
#  524.5703125,
#  624.125,
#  581.5546875,
#  766.046875,
#  646.5234375,
#  542.34375,
#  552.1015625,
#  628.8125,
#  489.0546875,
#  461.4609375,
#  628.390625,
#  591.8359375,
#  613.625,
#  767.1328125,
#  540.671875,
#  547.4609375,
#  588.6875,
#  639.5,
#  439.296875,
#  550.6328125,
#  636.3125,
#  552.8984375,
#  795.4140625,
#  614.890625,
#  539.78125,
#  588.7109375,
#  632.171875,
#  491.375,
#  440.859375,
#  610.828125,
#  611.6953125,
#  653.9609375,
#  741.84375,
#  493.9375,
#  535.84375,
#  654.1484375,
#  579.0859375,
#  413.3359375,
#  518.3828125,
#  600.15625,
#  573.1953125,
#  770.6875,
#  643.3828125,
#  503.671875,
#  563.890625,
#  623.5,
#  484.8515625,
#  445.9921875,
#  564.5546875,
#  602.2109375,
#  662.8359375,
#  708.8828125,
#  527.9453125,
#  529.421875,
#  620.1015625,
#  592.34375,
#  420.2890625,
#  542.6875,
#  636.171875,
#  560.859375,
#  786.2109375,
#  611.7265625,
#  514.296875,
#  603.0234375,
#  653.4921875,
#  482.0078125,
#  443.890625,
#  609.2890625,
#  613.3828125,
#  651.734375,
#  722.25,
#  525.6484375,
#  542.265625,
#  595.6875,
#  565.8515625,
#  435.5625,
#  556.2421875,
#  613.8046875,
#  552.9140625,
#  801.0078125,
#  594.3125,
#  488.9453125,
#  666.0390625,
#  795.5234375,
#  573.890625,
#  590.5078125,
#  755.359375,
#  756.6640625,
#  867.125,
#  821.5390625,
#  668.34375,
#  646.09375,
#  718.5,
#  682.4609375,
#  544.90625,
#  728.015625,
#  794.1796875,
#  553.5,
#  793.390625,
#  565.2265625,
#  534.7109375,
#  609.71875,
#  646.5546875,
#  431.59375,
#  481.2734375,
#  638.0234375,
#  596.328125,
#  735.6640625,
#  669.0,
#  543.2578125,
#  589.953125,
#  640.421875,
#  516.109375,
#  442.0234375,
#  596.40625,
#  610.6875,
#  570.2109375,
#  793.3515625,
#  540.796875,
#  507.7109375,
#  609.8671875,
#  648.3046875,
#  422.7734375,
#  490.03125,
#  606.078125,
#  561.34375,
#  755.8125,
#  630.640625,
#  534.8828125,
#  528.6796875,
#  608.9609375,
#  511.71875,
#  428.640625,
#  590.078125,
#  601.484375,
#  581.171875,
#  763.2421875,
#  541.515625,
#  501.6875,
#  590.2734375,
#  630.4453125,
#  425.9453125,
#  500.4765625,
#  630.2890625,
#  537.0859375,
#  798.3984375,
#  648.25,
#  540.6484375,
#  567.2734375,
#  626.96875,
#  490.4921875,
#  429.296875,
#  577.171875,
#  623.546875,
#  595.7890625,
#  741.921875,
#  534.828125,
#  533.5234375,
#  597.3046875,
#  600.984375,
#  440.484375,
#  514.4765625,
#  602.34375,
#  546.9296875,
#  775.9375,
#  610.5625,
#  513.890625,
#  575.421875,
#  604.296875,
#  477.328125,
#  432.3515625,
#  613.1015625,
#  624.1796875,
#  632.5703125,
#  708.40625,
#  526.5390625,
#  533.984375,
#  597.8046875,
#  596.984375,
#  419.828125,
#  542.640625,
#  648.921875,
#  557.078125,
#  760.4765625,
#  596.625,
#  489.7734375,
#  581.03125,
#  621.15625,
#  453.0859375,
#  409.7109375,
#  587.5078125,
#  605.625,
#  591.4921875,
#  745.109375,
#  502.15625,
#  524.65625,
#  571.359375,
#  570.8125,
#  420.7109375,
#  525.65625,
#  600.0703125,
#  566.5078125,
#  791.5625,
#  585.078125,
#  512.3046875,
#  588.671875,
#  582.484375,
#  468.96875,
#  443.3125,
#  595.7890625,
#  597.5,
#  687.2734375,
#  669.6171875,
#  506.078125,
#  551.6953125,
#  605.4921875,
#  557.3828125,
#  439.0234375,
#  521.7265625,
#  605.984375,
#  509.8515625,
#  743.0703125,
#  582.71875,
#  489.546875,
#  552.53125]

# %%
list_no_size_with_combine_cut = list_no_size_with_combine [5:240] # traditional
list_no_size_without_combine_cut = list_no_size_without_combine [5:240] # traditional
list_size_with_combine_cut = list_size_with_combine[5:240] 
list_size_without_combine_cut = list_size_without_combine[5:240]

# %%
fig = plt.figure(figsize = (10,6),dpi = 200)
plt.plot(range(0,len(list_no_size_without_combine_cut)), list_no_size_without_combine_cut, 'y', linestyle='-', linewidth=2)
plt.plot(range(0,len(list_no_size_with_combine_cut)), list_no_size_with_combine_cut, 'b', linestyle='-', linewidth=2)
plt.plot(range(0,len(list_size_without_combine_cut)), list_size_without_combine_cut, 'g', linestyle='-', linewidth=2)
plt.plot(range(0,len(list_size_with_combine_cut)), list_size_with_combine_cut, 'c', linestyle='-', linewidth=2)
plt.legend(('No_adjustmentsize_without_combine', 'No_adjustmentsize_with_combine','adjustmentsize_without_combine','adjustmentsize_with_combine'), loc='best',prop={'size': 10},fontsize="x-large") # 畫圖例及決定位置
plt.ylim(0,7500)
plt.tick_params(axis='both', labelsize=16)
#plt.title('Comparing different streaming architectures', fontsize=20)
plt.xlabel('Time (sec)', fontsize=16)
plt.ylabel('NetworkUsage (Kb/s)', fontsize=16)

plt.savefig('C:/Users/IPC_LAB/Desktop/data/picture/adjustmentsize_4.svg',pad_inches = 0.0)
plt.show()

# %%
Ave_no_size_with_combine = sum(list_no_size_with_combine_cut[5:240])/len(list_no_size_with_combine_cut[5:240])
Ave_no_size_with_combine
# Out:
# 2425.456351902174

# %%
Ave_no_size_without_combine = sum(list_no_size_without_combine_cut[5:240])/len(list_no_size_without_combine_cut[5:240])
Ave_no_size_without_combine
# Out:
# 2552.9893682065217

# %%
Ave_size_with_combine= sum(list_size_with_combine_cut[5:60])/len(list_size_with_combine_cut[5:240])
Ave_size_with_combine
# Out:
# 88.97133152173913

# %%
Ave_size_without_combine = sum(list_size_without_combine_cut[5:60])/len(list_size_without_combine_cut[5:240])
Ave_size_without_combine
# Out:
# 139.10859375

# %%
list_ServertoClientnetworkusage_with_optimization_cut[0:13]
# Out:
# [25.828125,
#  24.3828125,
#  24.28125,
#  25.0546875,
#  24.953125,
#  25.828125,
#  26.703125,
#  25.0546875,
#  25.828125,
#  18.8671875,
#  15.9765625,
#  11.03125,
#  13.453125]
