# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#df = pd.read_csv("./Desktop/碩論/數據資料/20220602/Networkusage/Combine_All_0710_1.csv")  # LARR
#df = pd.read_csv("./Desktop/碩論/數據資料/20220602/Networkusage/Combine_All_0710_without_optimization.csv")  # LARR_static
#df = pd.read_csv("./Desktop/碩論/數據資料/20220602/Networkusage/Combine_All_0710_old_streaming.csv") # Traditional
#df = pd.read_csv("C:/Users/IPC_LAB/Desktop/data/1_obj_without_sizeopt.csv")
#df = pd.read_csv("C:/Users/IPC_LAB/Desktop/data/1_obj_with_sizeopt.csv")
#df = pd.read_csv("C:/Users/IPC_LAB/Desktop/data/2obj_combine_without_sizeopt_1.csv")
df = pd.read_csv("C:/Users/IPC_LAB/Desktop/data/2obj_combine_with_sizeopt.csv")

# %%
df = df[~df['Protocol'].str.contains('STUN')]
df = df[~df['Protocol'].str.contains('TCP')]
df_data = df[~df['Protocol'].str.contains('HTTP')]
df_protocol = df_data.groupby('Protocol').Source.count()
df_protocol.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Protocol'>

# %%
#df_ClienttoServer = df_data[df_data['Source'] == '140.115.152.169']
df_ClienttoServer = df_data[df_data['Source'] == '140.115.197.252']
df_ServertoClient = df_data[df_data['Source'] == '140.115.152.173']
df_ServertoClient
# Out:
#          No.       Time           Source      Destination Protocol  Length  \
# 2          6   0.015727  140.115.152.173  140.115.197.252   RDPUDP    1279
# 3          7   0.015754  140.115.152.173  140.115.197.252   RDPUDP    1279
# 4          8   0.015762  140.115.152.173  140.115.197.252   RDPUDP    1279
# 5          9   0.015770  140.115.152.173  140.115.197.252   RDPUDP    1279
# 6         10   0.015811  140.115.152.173  140.115.197.252   RDPUDP    1282
# ...      ...        ...              ...              ...      ...     ...
# 11495  42864  60.848828  140.115.152.173  140.115.197.252   RDPUDP     362
# 11497  42866  60.849569  140.115.152.173  140.115.197.252   RDPUDP     283
# 11499  42884  60.877152  140.115.152.173  140.115.197.252   RDPUDP     388
# 11501  42889  60.892842  140.115.152.173  140.115.197.252   RDPUDP      53
# 11502  42893  60.897146  140.115.152.173  140.115.197.252   RDPUDP     397
#
#                      Info
# 2           CORRELATIONID
# 3           CORRELATIONID
# 4           CORRELATIONID
# 5           CORRELATIONID
# 6               SYNEX,AOA
# ...                   ...
# 11495                 AOA
# 11497                 AOA
# 11499                 AOA
# 11501  [Malformed Packet]
# 11502                 AOA
#
# [6207 rows x 7 columns]

# %%
#時間界線
lpper = 1
upper = 63

# %%
df_ClienttoServer = df_ClienttoServer[ df_ClienttoServer['Time'].between(lpper,upper)]
df_ClienttoServer
# Out:
#          No.       Time           Source      Destination Protocol  Length  \
# 148      674   1.005236  140.115.197.252  140.115.152.173   RDPUDP      60
# 156      695   1.042464  140.115.197.252  140.115.152.173   RDPUDP      60
# 157      701   1.050776  140.115.197.252  140.115.152.173   RDPUDP      60
# 161      719   1.094351  140.115.197.252  140.115.152.173   RDPUDP      60
# 162      722   1.096519  140.115.197.252  140.115.152.173   RDPUDP      60
# ...      ...        ...              ...              ...      ...     ...
# 11492  42843  60.808964  140.115.197.252  140.115.152.173   RDPUDP      60
# 11493  42847  60.816466  140.115.197.252  140.115.152.173   RDPUDP      60
# 11496  42865  60.849069  140.115.197.252  140.115.152.173   RDPUDP      60
# 11498  42878  60.871237  140.115.197.252  140.115.152.173   RDPUDP      60
# 11500  42886  60.883886  140.115.197.252  140.115.152.173   RDPUDP     272
#
#                           Info
# 148                        NaN
# 156                        NaN
# 157                      SYNEX
# 161         [Malformed Packet]
# 162         [Malformed Packet]
# ...                        ...
# 11492       [Malformed Packet]
# 11493  SYNEX[Malformed Packet]
# 11496       [Malformed Packet]
# 11498       [Malformed Packet]
# 11500                SYNEX,AOA
#
# [4232 rows x 7 columns]

# %%
df_ServertoClient = df_ServertoClient[ df_ServertoClient['Time'].between(lpper,upper) ]
df_ServertoClient
# Out:
#          No.       Time           Source      Destination Protocol  Length  \
# 149      675   1.014325  140.115.152.173  140.115.197.252   RDPUDP    1279
# 150      676   1.014346  140.115.152.173  140.115.197.252   RDPUDP    1279
# 151      677   1.014353  140.115.152.173  140.115.197.252   RDPUDP     147
# 152      678   1.017801  140.115.152.173  140.115.197.252   RDPUDP     358
# 155      694   1.037850  140.115.152.173  140.115.197.252   RDPUDP     352
# ...      ...        ...              ...              ...      ...     ...
# 11495  42864  60.848828  140.115.152.173  140.115.197.252   RDPUDP     362
# 11497  42866  60.849569  140.115.152.173  140.115.197.252   RDPUDP     283
# 11499  42884  60.877152  140.115.152.173  140.115.197.252   RDPUDP     388
# 11501  42889  60.892842  140.115.152.173  140.115.197.252   RDPUDP      53
# 11502  42893  60.897146  140.115.152.173  140.115.197.252   RDPUDP     397
#
#                      Info
# 149     CORRELATIONID,AOA
# 150     CORRELATIONID,AOA
# 151     CORRELATIONID,AOA
# 152     CORRELATIONID,AOA
# 155     CORRELATIONID,AOA
# ...                   ...
# 11495                 AOA
# 11497                 AOA
# 11499                 AOA
# 11501  [Malformed Packet]
# 11502                 AOA
#
# [6118 rows x 7 columns]

# %%
list_ServertoClientnetworkusage = []
list_axisxServertoClient = []
for i in range(lpper,upper):
    df_part = df_ServertoClient[ df_ServertoClient['Time'].between(i,i+1) ]
    totally_byte_per_second = df_part['Length'].sum()  #每秒多少bytes
    totally_bits_per_second = totally_byte_per_second * 8 #每秒多少bits
    Kbits_per_second = totally_bits_per_second / 1024
    list_ServertoClientnetworkusage.append(Kbits_per_second)
    list_axisxServertoClient.append(i)
    print( '使用了 {} Kb' .format(Kbits_per_second))
# Out:
# 使用了 626.140625 Kb
# 使用了 587.1953125 Kb
# 使用了 330.9140625 Kb
# 使用了 568.0078125 Kb
# 使用了 432.9453125 Kb
# 使用了 847.859375 Kb
# 使用了 830.0625 Kb
# 使用了 697.5 Kb
# 使用了 678.5625 Kb
# 使用了 651.375 Kb
# 使用了 682.8828125 Kb
# 使用了 549.59375 Kb
# 使用了 573.5078125 Kb
# 使用了 778.9296875 Kb
# 使用了 539.0078125 Kb
# 使用了 449.640625 Kb
# 使用了 333.0 Kb
# 使用了 352.5 Kb
# 使用了 313.7265625 Kb
# 使用了 313.578125 Kb
# 使用了 256.578125 Kb
# 使用了 256.234375 Kb
# 使用了 328.2421875 Kb
# 使用了 383.0625 Kb
# 使用了 667.71875 Kb
# 使用了 440.671875 Kb
# 使用了 435.1015625 Kb
# 使用了 337.9765625 Kb
# 使用了 321.390625 Kb
# 使用了 307.1171875 Kb
# 使用了 557.875 Kb
# 使用了 1365.7890625 Kb
# 使用了 1013.4375 Kb
# 使用了 1099.21875 Kb
# 使用了 1100.609375 Kb
# 使用了 842.34375 Kb
# 使用了 920.953125 Kb
# 使用了 912.8125 Kb
# 使用了 975.5546875 Kb
# 使用了 821.625 Kb
# 使用了 854.953125 Kb
# 使用了 968.8359375 Kb
# 使用了 504.6171875 Kb
# 使用了 709.765625 Kb
# 使用了 517.953125 Kb
# 使用了 424.765625 Kb
# 使用了 145.6875 Kb
# 使用了 135.9296875 Kb
# 使用了 132.625 Kb
# 使用了 135.3046875 Kb
# 使用了 362.21875 Kb
# 使用了 696.234375 Kb
# 使用了 288.1640625 Kb
# 使用了 298.765625 Kb
# 使用了 232.7734375 Kb
# 使用了 420.1875 Kb
# 使用了 237.78125 Kb
# 使用了 256.765625 Kb
# 使用了 333.78125 Kb
# 使用了 229.5546875 Kb
# 使用了 0.0 Kb
# 使用了 0.0 Kb

# %%
list_ClienttoServernetworkusage = []
list_axisxClienttoServer = []
for i in range(lpper,upper):
    df_part = df_ClienttoServer[ df_ClienttoServer['Time'].between(i,i+1) ]
    totally_byte_per_second = df_part['Length'].sum()  #每秒多少bytes
    totally_bits_per_second = totally_byte_per_second * 8 #每秒多少bits
    Kbits_per_second = totally_bits_per_second / 1024
    list_ClienttoServernetworkusage.append(Kbits_per_second)
    list_axisxClienttoServer.append(i)
    print( '使用了 {} Kb' .format(Kbits_per_second))
# Out:
# 使用了 30.203125 Kb
# 使用了 61.390625 Kb
# 使用了 31.4375 Kb
# 使用了 84.0703125 Kb
# 使用了 55.5 Kb
# 使用了 75.171875 Kb
# 使用了 59.328125 Kb
# 使用了 58.8203125 Kb
# 使用了 78.6484375 Kb
# 使用了 66.375 Kb
# 使用了 34.984375 Kb
# 使用了 34.0234375 Kb
# 使用了 35.3671875 Kb
# 使用了 36.71875 Kb
# 使用了 33.078125 Kb
# 使用了 37.703125 Kb
# 使用了 31.625 Kb
# 使用了 30.7578125 Kb
# 使用了 32.609375 Kb
# 使用了 27.109375 Kb
# 使用了 30.765625 Kb
# 使用了 26.484375 Kb
# 使用了 28.4296875 Kb
# 使用了 30.734375 Kb
# 使用了 31.3125 Kb
# 使用了 33.8984375 Kb
# 使用了 35.90625 Kb
# 使用了 45.859375 Kb
# 使用了 36.765625 Kb
# 使用了 32.6015625 Kb
# 使用了 32.2109375 Kb
# 使用了 46.2265625 Kb
# 使用了 42.8671875 Kb
# 使用了 42.8984375 Kb
# 使用了 50.71875 Kb
# 使用了 38.7109375 Kb
# 使用了 43.3359375 Kb
# 使用了 35.96875 Kb
# 使用了 45.7265625 Kb
# 使用了 47.1875 Kb
# 使用了 61.71875 Kb
# 使用了 42.1484375 Kb
# 使用了 39.5859375 Kb
# 使用了 54.96875 Kb
# 使用了 50.484375 Kb
# 使用了 58.046875 Kb
# 使用了 43.65625 Kb
# 使用了 34.7890625 Kb
# 使用了 19.3046875 Kb
# 使用了 46.7109375 Kb
# 使用了 43.84375 Kb
# 使用了 77.65625 Kb
# 使用了 40.9140625 Kb
# 使用了 23.90625 Kb
# 使用了 22.59375 Kb
# 使用了 28.1796875 Kb
# 使用了 24.28125 Kb
# 使用了 22.75 Kb
# 使用了 22.4453125 Kb
# 使用了 19.7578125 Kb
# 使用了 0.0 Kb
# 使用了 0.0 Kb

# %%
fig = plt.figure()
#list_ServertoClientnetworkusage[8:15] = list_ServertoClientnetworkusage[0:7]
plt.plot(list_axisxClienttoServer, list_ClienttoServernetworkusage, 'r')
plt.plot(list_axisxServertoClient, list_ServertoClientnetworkusage, 'g')
plt.legend(('Client to Server', 'Server to Client'), loc='best') # 畫圖例及決定位置
plt.title('Multiplane Streaming')
plt.xlabel('Sample number (sec)')
plt.ylabel('NetworkUsage (Kb)')
plt.show()

# %%
mean_Client_to_Server = sum(list_ClienttoServernetworkusage) / len(list_axisxClienttoServer)
mean_Server_to_Client = sum(list_ServertoClientnetworkusage) / len(list_axisxServertoClient)
print('平均每秒串流至Client的影像資料為 {} Kb'.format(mean_Server_to_Client))
print('平均每秒傳輸至Server的控制資料為 {} Kb'.format(mean_Client_to_Server))
# Out:
# 平均每秒串流至Client的影像資料為 522.063004032258 Kb
# 平均每秒傳輸至Server的控制資料為 39.85924899193548 Kb

# %%
list_ServertoClientnetworkusagecut = list_ServertoClientnetworkusage[0:30]
print(list_ServertoClientnetworkusagecut)
mean_Server_to_Client_cut = sum(list_ServertoClientnetworkusagecut) / len(list_ServertoClientnetworkusagecut)
print('平均每秒串流至Client的影像資料為 {} Kb (無傳輸任何物件)'.format(mean_Server_to_Client_cut))
# Out:
# [626.140625, 587.1953125, 330.9140625, 568.0078125, 432.9453125, 847.859375, 830.0625, 697.5, 678.5625, 651.375, 682.8828125, 549.59375, 573.5078125, 778.9296875, 539.0078125, 449.640625, 333.0, 352.5, 313.7265625, 313.578125, 256.578125, 256.234375, 328.2421875, 383.0625, 667.71875, 440.671875, 435.1015625, 337.9765625, 321.390625, 307.1171875]
# 平均每秒串流至Client的影像資料為 495.70078125 Kb (無傳輸任何物件)

# %%
list_ServertoClientnetworkusage_with_optimization = list_ServertoClientnetworkusage # LARR

# %%
list_ServertoClientnetworkusage_with_optimization # LARR
# Out:
# [626.140625,
#  587.1953125,
#  330.9140625,
#  568.0078125,
#  432.9453125,
#  847.859375,
#  830.0625,
#  697.5,
#  678.5625,
#  651.375,
#  682.8828125,
#  549.59375,
#  573.5078125,
#  778.9296875,
#  539.0078125,
#  449.640625,
#  333.0,
#  352.5,
#  313.7265625,
#  313.578125,
#  256.578125,
#  256.234375,
#  328.2421875,
#  383.0625,
#  667.71875,
#  440.671875,
#  435.1015625,
#  337.9765625,
#  321.390625,
#  307.1171875,
#  557.875,
#  1365.7890625,
#  1013.4375,
#  1099.21875,
#  1100.609375,
#  842.34375,
#  920.953125,
#  912.8125,
#  975.5546875,
#  821.625,
#  854.953125,
#  968.8359375,
#  504.6171875,
#  709.765625,
#  517.953125,
#  424.765625,
#  145.6875,
#  135.9296875,
#  132.625,
#  135.3046875,
#  362.21875,
#  696.234375,
#  288.1640625,
#  298.765625,
#  232.7734375,
#  420.1875,
#  237.78125,
#  256.765625,
#  333.78125,
#  229.5546875,
#  0.0,
#  0.0]

# %%
list_ServertoClientnetworkusage_without_optimization = list_ServertoClientnetworkusage # LARR_static

# %%
list_ServertoClientnetworkusage_without_optimization # LARR_static
# Out:
# [621.9609375,
#  555.9375,
#  501.609375,
#  1471.8125,
#  1928.390625,
#  2489.40625,
#  2339.6484375,
#  2196.625,
#  2867.078125,
#  2147.734375,
#  2101.7421875,
#  2449.625,
#  2105.6484375,
#  1651.59375,
#  2129.8203125,
#  2569.1796875,
#  2454.0,
#  2612.0703125,
#  2424.6328125,
#  2236.6796875,
#  2165.78125,
#  2330.84375,
#  1879.9765625,
#  1698.09375,
#  2408.2734375,
#  2514.609375,
#  1938.8984375,
#  2665.7578125,
#  2267.28125,
#  1889.75,
#  2749.53125,
#  4402.8046875,
#  1473.1484375,
#  3043.84375,
#  2725.71875,
#  1497.953125,
#  1788.4375,
#  1743.484375,
#  1488.3828125,
#  1753.453125,
#  1508.8359375,
#  1312.2421875,
#  1025.5078125,
#  1409.96875,
#  844.3984375,
#  1460.1796875,
#  1559.9375,
#  697.2734375,
#  1294.296875,
#  1022.1953125,
#  1321.71875,
#  994.28125,
#  1014.0703125,
#  1144.4765625,
#  708.4453125,
#  357.8515625,
#  459.7109375,
#  417.984375,
#  340.1640625,
#  220.9921875,
#  0.0,
#  0.0]

# %%
list_ServertoClientnetworkusage_old_streaming = list_ServertoClientnetworkusage # Traditional

# %%
list_ServertoClientnetworkusage_old_streaming # Traditional
# Out:
# [0.0,
#  0.0,
#  771.484375,
#  900.515625,
#  735.7890625,
#  746.953125,
#  1018.03125,
#  765.71875,
#  1010.2734375,
#  867.734375,
#  880.5078125,
#  930.25,
#  920.9921875,
#  783.40625,
#  793.1796875,
#  870.8203125,
#  802.2265625,
#  943.9609375,
#  943.4921875,
#  989.875,
#  808.8125,
#  808.9609375,
#  803.8828125,
#  988.8671875,
#  808.53125,
#  864.046875,
#  692.203125,
#  985.609375,
#  969.8046875,
#  815.6484375,
#  983.703125,
#  824.265625,
#  986.6171875,
#  779.078125,
#  1151.515625,
#  733.046875,
#  966.6015625,
#  917.8515625,
#  880.109375,
#  809.34375,
#  887.0,
#  815.828125,
#  952.6953125,
#  799.1171875,
#  837.3828125,
#  787.4296875,
#  813.9296875,
#  812.09375,
#  960.7578125,
#  1286.765625,
#  938.1875,
#  731.78125,
#  818.21875,
#  857.5546875,
#  851.8203125,
#  816.34375,
#  758.4453125,
#  819.90625,
#  819.3203125,
#  709.1953125,
#  790.8046875,
#  963.90625,
#  748.4921875,
#  0.0]

# %%
#list_ServertoClientnetworkusage_old_streaming_cut = list_ServertoClientnetworkusage_old_streaming[6:166] # traditional
list_ServertoClientnetworkusage_with_optimization_cut = list_ServertoClientnetworkusage_with_optimization[1:60] # LARR
list_ServertoClientnetworkusage_without_optimization_cut = list_ServertoClientnetworkusage_without_optimization[1:60] # LARR_static

# %%
fig = plt.figure(figsize = (10,6),dpi = 200)
plt.plot(range(0,len(list_ServertoClientnetworkusage_with_optimization_cut)), list_ServertoClientnetworkusage_with_optimization_cut, 'y', linestyle='-', linewidth=3)
plt.plot(range(0,len(list_ServertoClientnetworkusage_without_optimization_cut)), list_ServertoClientnetworkusage_without_optimization_cut, 'b', linestyle='-', linewidth=3)
#plt.plot(range(0,len(list_ServertoClientnetworkusage_old_streaming_cut)), list_ServertoClientnetworkusage_old_streaming_cut, 'c', linestyle='-', linewidth=3)
plt.legend(('LARR_with_adjustmentsize', 'LARR_without_adjustmentsize',), loc='best',prop={'size': 12},fontsize="x-large") # 畫圖例及決定位置
plt.ylim(0,4500)
plt.tick_params(axis='both', labelsize=16)
#plt.title('Comparing different streaming architectures', fontsize=20)
plt.xlabel('Time (sec)', fontsize=16)
plt.ylabel('NetworkUsage (Kb/s)', fontsize=16)

plt.savefig('C:/Users/IPC_LAB/Desktop/data/picture/adjustmentsize.jpg',pad_inches = 0.0)
plt.show()

# %%
Ave_object_traditional = sum(list_ServertoClientnetworkusage_old_streaming_cut[13:150])/len(list_ServertoClientnetworkusage_old_streaming_cut[13:150])
Ave_object_traditional
# Out:
# 2585.8040031934306

# %%
Ave_object_LARR = sum(list_ServertoClientnetworkusage_with_optimization_cut[31:60])/len(list_ServertoClientnetworkusage_with_optimization_cut[31:60])
Ave_object_LARR
# Out:
# 556.1863839285714

# %%
Ave_object_LARR_static = sum(list_ServertoClientnetworkusage_without_optimization_cut[0:30])/len(list_ServertoClientnetworkusage_without_optimization_cut[0:30])
Ave_object_LARR_static
# Out:
# 2124.734375

# %%
Ave_noobject_traditional = sum(list_ServertoClientnetworkusage_old_streaming_cut[0:30])/len(list_ServertoClientnetworkusage_old_streaming_cut[0:30])
Ave_noobject_traditional
# Out:
# 112.0625

# %%
Ave_noobject_LARR = sum(list_ServertoClientnetworkusage_with_optimization_cut[0:13])/len(list_ServertoClientnetworkusage_with_optimization_cut[0:13])
Ave_noobject_LARR
# Out:
# 22.095552884615383

# %%
list_ServertoClientnetworkusage_with_optimization_cut[0:13]
# Out:
# [25.828125,
#  24.3828125,
#  24.28125,
#  25.0546875,
#  24.953125,
#  25.828125,
#  26.703125,
#  25.0546875,
#  25.828125,
#  18.8671875,
#  15.9765625,
#  11.03125,
#  13.453125]
